# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruthwik8888/NLP-Assessments/blob/NLP/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Integer
my_integer = 42
print("Value:", my_integer, "| Type:", type(my_integer))

# Float
my_float = 3.14
print("Value:", my_float, "| Type:", type(my_float))

# String
my_string = "Hello, Jupyter!"
print("Value:", my_string, "| Type:", type(my_string))

# Boolean
my_boolean = True
print("Value:", my_boolean, "| Type:", type(my_boolean))
# Out:
# Value: 42 | Type: <class 'int'>
# Value: 3.14 | Type: <class 'float'>
# Value: Hello, Jupyter! | Type: <class 'str'>
# Value: True | Type: <class 'bool'>
